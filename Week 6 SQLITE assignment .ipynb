# %% [markdown]
# ## Assignment 5 - SET 1
# ## Kinjalk Parth | RA1911026010037

# %%
import sqlite3
conn = sqlite3.connect('StudentDB1.db')
print("Connected to database successfully")
try:
    conn.execute('''
        CREATE TABLE IF NOT EXISTS student(id integer primary key, 
                      fname text,
                      lname text,
                      dob text,
                      email text,
                      mobno text,
                      gender text,
                      address text,
                      city text,
                      pincode text,
                      state text,
                      country text,
                      hobbies text,
                      board1 text,
                      percentage1 float,
                      yop1 int,
                      board2 text,
                      percentage2 float,
                      yop2 int,
                      board3 text,
                      percentage3 float,
                      yop3 int,
                      board4 text,
                      percentage4 float,
                      yop4 int,
                      course text 
                      );''')
    conn.commit()
    print("Student Table created successfully")
except sqlite3.Error as my_error:
  print("error: ",my_error)
# Out:
# Connected to database successfully
# Student Table created successfully

# %%
import tkinter as tk
from tkinter import messagebox
from PIL import Image
from PIL import ImageTk
root_0048 = tk.Tk()

#---------------------------------Input Data Collection-------------------------------------------------------------------------

fname_inp = tk.StringVar()
fname_inp = tk.StringVar()
lname_inp = tk.StringVar()
lname_inp = tk.StringVar()
dob_day_inp = tk.IntVar()
dob_month_inp = tk.IntVar()
dob_year_inp = tk.IntVar()
email_inp = tk.StringVar()
city_inp = tk.StringVar()
mobno_inp = tk.StringVar()
state_inp = tk.StringVar()
pinc_inp = tk.StringVar() or tk.IntVar()
country_inp = tk.StringVar()
otrrsn_inp = tk.StringVar()
board1_inp = tk.StringVar()
board2_inp = tk.StringVar()
board3_inp = tk.StringVar()
board3_inp.set(" ")
board4_inp = tk.StringVar()
board4_inp.set(" ")
percentage1_inp = tk.DoubleVar()
percentage2_inp = tk.DoubleVar()
percentage3_inp = tk.DoubleVar()
#percentage3_inp.set("")
percentage4_inp = tk.DoubleVar()
#percentage3_inp.set("")
yop1_inp = tk.IntVar()
yop2_inp = tk.IntVar()
yop3_inp = tk.IntVar()
#yop3_inp.set("")
yop4_inp = tk.IntVar()
#yop4_inp.set("")

radio = tk.IntVar()
radio1 = tk.IntVar()
check_bx = tk.IntVar()
check_bx1 = tk.IntVar()
check_bx2 = tk.IntVar()
check_bx3 = tk.IntVar()
check_bx4 = tk.IntVar()
#-------------------------------------------------------------------------------------------------------------------------------

m2canvas = tk.Canvas(width=800, height=1200, bg='slateblue', scrollregion=(0,0,1200,1200))
vbar=tk.Scrollbar(m2canvas,orient='vertical')
vbar.pack(side='right',fill='y')
vbar.config(command=m2canvas.yview)
m2canvas.config(yscrollcommand=vbar.set)
#All Labels

label_1 = tk.Label(root_0048, text='STUDENT REGISTRATION FORM', bg='white', font=('Helvetica 8 underline',15, 'bold', 
                                                                             'underline'), fg='slateblue')
label_1.pack(fill='x')
f_name_label = tk.Label(root_0048, text='First Name', bg='slateblue', font=('none',12),fg='white')
f_name_label.pack()
l_name_label = tk.Label(root_0048, text='Last Name', bg='slateblue', font=('none',12),fg='white')
l_name_label.pack()
dob_label = tk.Label(root_0048, text='Date of Birth', bg='slateblue', font=('none',12),fg='white')
dob_label.pack()
email_label = tk.Label(root_0048, text='Email', bg='slateblue', font=('none',12),fg='white')
email_label.pack()
mobno_label = tk.Label(root_0048, text='Mobile Number', bg='slateblue', font=('none',12),fg='white')
mobno_label.pack()
gender_label = tk.Label(root_0048, text='Gender', bg='slateblue', font=('none',12),fg='white')
gender_label.pack()
add_label = tk.Label(root_0048, text='Address', bg='slateblue', font=('none',12),fg='white')
add_label.pack()
city_label = tk.Label(root_0048, text='City', bg='slateblue', font=('none',12),fg='white')
city_label.pack()
pinc_label = tk.Label(root_0048, text='Pincode', bg='slateblue', font=('none',12),fg='white')
pinc_label.pack()
state_label = tk.Label(root_0048, text='State', bg='slateblue', font=('none',12),fg='white')
state_label.pack()
country_label = tk.Label(root_0048, text='Country', bg='slateblue', font=('none',12),fg='white')
country_label.pack()
hobby_label = tk.Label(root_0048, text='Hobby', bg='slateblue', font=('none',12),fg='white')
hobby_label.pack()
qualification_label = tk.Label(root_0048, text='Qualification', bg='slateblue', font=('none',12),fg='white')
qualification_label.pack()
siNo_label = tk.Label(root_0048, text='SI.No.', bg='slateblue', font=('none',10,'bold'),fg='white')
siNo_label.pack()
exam_label = tk.Label(root_0048, text='Examination', bg='slateblue', font=('none',10,'bold'),fg='white')
exam_label.pack()
board_label = tk.Label(root_0048, text='Board', bg='slateblue', font=('none',10,'bold'),fg='white')
board_label.pack()
percentage_label = tk.Label(root_0048, text='Percentage', bg='slateblue', font=('none',10,'bold'),fg='white')
percentage_label.pack()
yop_label = tk.Label(root_0048, text='Year of Passing', bg='slateblue', font=('none',10,'bold'),fg='white')
yop_label.pack()
courses_label = tk.Label(root_0048, text='Courses Applied For', bg='slateblue', font=('none',12),fg='white')
courses_label.pack()

#text 

 #warnings
warn1 = tk.Label(root_0048,text='(max 30 character A-Z and a-z)', bg='slateblue', font=('none',10,'bold'),fg='white')
warn1.pack()
warn2 = tk.Label(root_0048,text='(max 30 character A-Z and a-z)', bg='slateblue', font=('none',10,'bold'),fg='white')
warn2.pack()
warn3 = tk.Label(root_0048,text='(10 digit number)', bg='slateblue', font=('none',10,'bold'),fg='white')
warn3.pack()
warn4 = tk.Label(root_0048,text='(max 30 character A-Z and a-z)', bg='slateblue', font=('none',10,'bold'),fg='white')
warn4.pack()
warn5 = tk.Label(root_0048,text='(6 digit number)', bg='slateblue', font=('none',10,'bold'),fg='white')
warn5.pack()
warn6 = tk.Label(root_0048,text='(max 30 character A-Z and a-z)', bg='slateblue', font=('none',10,'bold'),fg='white')
warn6.pack()
warn7 = tk.Label(root_0048,text='(10 char max)', bg='slateblue', font=('none',10,'bold'),fg='white')
warn7.pack()
warn8 = tk.Label(root_0048,text='(upto 2 decimal)', bg='slateblue', font=('none',10,'bold'),fg='white')
warn8.pack()

 #SINo's
sno1 = tk.Label(root_0048,text='1', bg='slateblue', font=('none',10,'bold'),fg='white')
sno1.pack()
sno2 = tk.Label(root_0048,text='2', bg='slateblue', font=('none',10,'bold'),fg='white')
sno2.pack()
sno3 = tk.Label(root_0048,text='3', bg='slateblue', font=('none',10,'bold'),fg='white')
sno3.pack()
sno4 = tk.Label(root_0048,text='4', bg='slateblue', font=('none',10,'bold'),fg='white')
sno4.pack()

 #Examination
exam1 = tk.Label(root_0048,text='Class X', bg='slateblue', font=('none',10,'bold'),fg='white')
exam1.pack()
exam2 = tk.Label(root_0048,text='Class XII', bg='slateblue', font=('none',10,'bold'),fg='white')
exam2.pack()
exam3 = tk.Label(root_0048,text='Graduation', bg='slateblue', font=('none',10,'bold'),fg='white')
exam3.pack()
exam4 = tk.Label(root_0048,text='Masters', bg='slateblue', font=('none',10,'bold'),fg='white')
exam4.pack()

#Widgets

f_name = tk.Entry(root_0048, textvariable = fname_inp, font=('none',12))
f_name.place(width = 40, height = 12)
l_name = tk.Entry(root_0048, textvariable = lname_inp, font=('none',12))
l_name.place(width = 40, height = 12)
dob_day = tk.Spinbox(root_0048, from_=1, to=31, textvariable = dob_day_inp, width=6)
dob_day.place(width=5, height=5)
#dob_day.insert(0,"Day:")
dob_month = tk.Spinbox(root_0048, from_=1, to=12, textvariable = dob_month_inp, width=8)
dob_month.place(width=5, height=10)
#dob_month.insert(0,"Month:")
dob_year = tk.Spinbox(root_0048, from_=1970, to=2021, textvariable = dob_year_inp, width=10)
dob_year.place(width=5, height=5)
#dob_year.insert(0,"Year:")
email = tk.Entry(root_0048, textvariable = email_inp, font=('none',12))
email.place(width=40, height=12)

mobno = tk.Entry(root_0048, textvariable = mobno_inp, font=('none',12))
mobno.place(width=40, height=12)

gmale_btn = tk.Radiobutton(root_0048, text='Male', bg='slateblue', fg = 'white',selectcolor='black', variable=radio, value=1)
gmale_btn.pack()

gfmale_btn = tk.Radiobutton(root_0048, text='Female', bg='slateblue', fg = 'white',selectcolor='black', variable=radio, value=2)
gfmale_btn.pack()

addr = tk.Text(root_0048, height = 5, width =30)
addr.pack()

city = tk.Entry(root_0048, textvariable = city_inp, font=('none',12))
city.place(width=40, height=12)

pinc = tk.Entry(root_0048, textvariable = pinc_inp, font=('none',12))
pinc.place(width=40, height=12)

state = tk.Entry(root_0048, textvariable = state_inp, font=('none',12))
state.place(width=40, height=12)

country = tk.Entry(root_0048, textvariable = country_inp, font=('none',12))
country.insert(0,'India')
country.place(width=40, height=12)

drawing = tk.Checkbutton(root_0048, text='Drawing', bg='slateblue', fg = 'white', variable=check_bx, selectcolor = 'black')
drawing.pack()
singing = tk.Checkbutton(root_0048, text='Singing', bg='slateblue', fg = 'white', variable=check_bx1, selectcolor='black')
singing.pack()
dancing = tk.Checkbutton(root_0048, text='Dancing', bg='slateblue', fg = 'white', variable=check_bx2, selectcolor='black')
dancing.pack()
sketching = tk.Checkbutton(root_0048, text='Sketching', bg='slateblue', fg = 'white', variable=check_bx3, selectcolor='black')
sketching.pack()
others = tk.Checkbutton(root_0048, text='Others', bg='slateblue', fg = 'white', variable=check_bx4, selectcolor='black', 
                        command =lambda:warns())
others.pack()
otrrsn = tk.Entry(root_0048, textvariable = otrrsn_inp, font=('none',12))
otrrsn.place(width=40, height=12)

board1 = tk.Entry(root_0048, textvariable = board1_inp, font=('none',12))
board1.place(width=40, height=12)
board2 = tk.Entry(root_0048, textvariable = board2_inp, font=('none',12))
board2.place(width=40, height=12)
board3 = tk.Entry(root_0048, textvariable = board3_inp, font=('none',12))
board3.place(width=40, height=12)
board4 = tk.Entry(root_0048, textvariable = board4_inp, font=('none',12))
board4.place(width=40, height=12)

percentage1 = tk.Entry(root_0048, textvariable = percentage1_inp, font=('none',12))
percentage1.place(width=40, height=12)
percentage2 = tk.Entry(root_0048, textvariable = percentage2_inp, font=('none',12))
percentage2.place(width=40, height=12)
percentage3 = tk.Entry(root_0048, textvariable = percentage3_inp, font=('none',12))
percentage3.place(width=40, height=12)
percentage4 = tk.Entry(root_0048, textvariable = percentage4_inp, font=('none',12))
percentage4.place(width=40, height=12)

yop1 = tk.Entry(root_0048, textvariable = yop1_inp, font=('none',12))
yop1.place(width=40, height=12)
yop2 = tk.Entry(root_0048, textvariable = yop2_inp, font=('none',12))
yop2.place(width=40, height=12)
yop3 = tk.Entry(root_0048, textvariable = yop3_inp, font=('none',12))
yop3.place(width=40, height=12)
yop4 = tk.Entry(root_0048, textvariable = yop4_inp, font=('none',12))
yop4.place(width=40, height=12)

bca_btn = tk.Radiobutton(root_0048, text='BCA', bg='slateblue', fg = 'white', selectcolor='black', variable=radio1, value = 1)
bca_btn.pack()
bcom_btn = tk.Radiobutton(root_0048, text='B.Com', bg='slateblue', fg = 'white', selectcolor='black', variable=radio1, value =2)
bcom_btn.pack()
bsc_btn = tk.Radiobutton(root_0048, text='BSc', bg='slateblue', fg = 'white', selectcolor='black', variable=radio1, value = 3)
bsc_btn.pack()
ba_btn = tk.Radiobutton(root_0048, text='BA', bg='slateblue', fg = 'white', selectcolor='black', variable=radio1, value = 4)
ba_btn.pack()

submit_btn = tk.Button(root_0048, text='SUBMIT', command=lambda:add_data())
reset_btn = tk.Button(root_0048, text='RESET', command=lambda:reset())

#function to add data to database and assigning values to string vars

def gndr():
    my_gndr = ""
    if(radio.get()==1):
        my_gndr = 'Male'
    elif(radio.get()==2):
        my_gndr = 'Female'
    return my_gndr
def hbies():
    my_hbie = ""
    if(check_bx.get()==1):
        my_hbie += 'Drawing,'
    if(check_bx.get()==1):
        my_hbie += 'Singing,'
    if(check_bx.get()==1):
        my_hbie += 'Dancing,'
    if(check_bx.get()==1):
        my_hbie += 'Sketching,'
    return my_hbie
def crs():
    my_crcs = ""
    if(radio1.get()==1):
        my_crcs = 'BCA'
    elif(radio1.get()==2):
        my_crcs = 'B.Com'
    elif(radio1.get()==3):
        my_crcs = 'BSc'
    elif(radio1.get()==4):
        my_crcs = 'BA'
    return my_crcs
def warns():
    if check_bx4.get() ==1:
        messagebox.showinfo("Others","Please write other hobbies in the text box")
                               
def add_data():
    flag_val=True
    my_str = tk.StringVar()
    my_fname = fname_inp.get()
    my_lname = lname_inp.get()
    my_dob = str(dob_day_inp.get()) + '/' + str(dob_month_inp.get()) + '/' + str(dob_year_inp.get())
    my_email = email_inp.get()
    my_mobno = mobno_inp.get()
    my_gender = gndr()
    my_addr = addr.get("1.0",'end')
    my_city = city_inp.get()
    my_pinc = pinc_inp.get()
    my_state = state_inp.get()
    my_country = country_inp.get()
    my_hobbie = hbies()
    my_board1 = board1_inp.get()
    my_board2 = board2_inp.get()
    my_board3 = board3_inp.get()
    my_board4 = board4_inp.get()
    my_percentage1 = percentage1_inp.get()
    my_percentage2 = percentage2_inp.get()
    my_percentage3 = percentage3_inp.get()
    my_percentage4 = percentage4_inp.get()
    my_yop1 = yop1_inp.get()
    my_yop2 = yop2_inp.get()
    my_yop3 = yop3_inp.get()
    my_yop4 = yop4_inp.get()
    my_course = crs()
    if(len(my_fname) > 30 or len(my_fname) < 2 or len(my_lname) < 2 or len(my_lname) > 30  or len(my_mobno) >10
       or len(my_city)>30 or len(my_pinc)>6 or len(my_state)>30):
        flag_val=False
    if(flag_val):
        my_str.set("Adding Data.....")
        try:
    
            my_data = (None,my_fname,my_lname,my_dob,my_email,my_mobno,my_gender,my_addr,my_city,my_pinc,my_state,
                       my_country,my_hobbie,my_board1,my_percentage1,my_yop1,my_board2,my_percentage2,my_yop2,
                       my_board3,my_percentage3,my_yop3,my_board4,my_percentage4,my_yop4,my_course)
            my_query = "INSERT INTO student values(?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?)"
            conn.execute(my_query,my_data)
            conn.commit()
            x=conn.execute('''select last_insert_rowid()''')
            id = x.fetchone()
            my_str.set("ID: "+str(id[0]))
            messagebox.showinfo("Success", my_str.get())
            
        except sqlite3.Error as my_error:
            my_str.set(my_error)
            messagebox.showerror("Error",my_str.get())
    else:
        messagebox.showwarning("Input","Check Inputs")

def reset():
    fname_inp.set("")
    lname_inp.set("")
#     dob_day.insert(0,"1")
#     dob_month.insert(0,"1")
#     dob_year.insert(0,"1970")
    email_inp.set("")
    mobno_inp.set("")
    city_inp.set("")
    addr.delete("1.0",'end')
    pinc_inp.set("")
    state_inp.set("")
    country_inp.set("")
    board1_inp.set("")
    board2_inp.set("")
    board3_inp.set("")
    board4_inp.set("")
    percentage1_inp.set("0.0")
    percentage2_inp.set("0.0")
    percentage3_inp.set("0.0")
    percentage4_inp.set("0.0")
    yop1_inp.set("0")
    yop2_inp.set("0")
    yop3_inp.set("0")
    yop4_inp.set("0")

#window creation
m2canvas.pack(expand=True, fill='both')
#m2canvas.create_window(400,25,window=label_1)
m2canvas.create_window(50,55, window=f_name_label)
m2canvas.create_window(267,55,window=f_name)
m2canvas.create_window(480,55,window=warn1)
m2canvas.create_window(50,105,window=l_name_label)
m2canvas.create_window(267,105,window=l_name)
m2canvas.create_window(480,105,window=warn2)
m2canvas.create_window(55,155,window=dob_label)
m2canvas.create_window(201,155,window=dob_day)
m2canvas.create_window(271,155,window=dob_month)
m2canvas.create_window(361,155,window=dob_year)
m2canvas.create_window(35,205,window=email_label)
m2canvas.create_window(267,205,window=email)
m2canvas.create_window(67,255,window=mobno_label)
m2canvas.create_window(267,255,window=mobno)
m2canvas.create_window(440,255,window=warn3)
m2canvas.create_window(40,305,window=gender_label)
m2canvas.create_window(200,305,window=gmale_btn)
m2canvas.create_window(270,305,window=gfmale_btn)
m2canvas.create_window(43,355,window=add_label)
m2canvas.create_window(297,385,window=addr)
m2canvas.create_window(23,455,window=city_label)
m2canvas.create_window(40,505,window=pinc_label)
m2canvas.create_window(30,555,window=state_label)
m2canvas.create_window(37,605,window=country_label)
m2canvas.create_window(267,455,window=city)
m2canvas.create_window(480,455,window=warn4)
m2canvas.create_window(267,505,window=pinc)
m2canvas.create_window(435,505,window=warn5)
m2canvas.create_window(267,555,window=state)
m2canvas.create_window(480,555,window=warn6)
m2canvas.create_window(267,605,window=country)
m2canvas.create_window(35,655,window=hobby_label)
m2canvas.create_window(205,655,window=drawing)
m2canvas.create_window(270,655,window=singing)
m2canvas.create_window(337,655,window=dancing)
m2canvas.create_window(407,655,window=sketching)
m2canvas.create_window(200,675,window=others)
m2canvas.create_window(337,675,window=otrrsn)
m2canvas.create_window(57,725,window=qualification_label)
m2canvas.create_window(200,705,window=siNo_label)
m2canvas.create_window(270,705,window=exam_label)
m2canvas.create_window(450,705,window=board_label)
m2canvas.create_window(650,705,window=percentage_label)
m2canvas.create_window(850,705,window=yop_label)
m2canvas.create_window(200,730,window=sno1)
m2canvas.create_window(200,755,window=sno2)
m2canvas.create_window(200,780,window=sno3)
m2canvas.create_window(200,805,window=sno4)
m2canvas.create_window(270,730,window=exam1)
m2canvas.create_window(270,755,window=exam2)
m2canvas.create_window(270,780,window=exam3)
m2canvas.create_window(270,805,window=exam4)
m2canvas.create_window(450,730,window=board1)
m2canvas.create_window(450,755,window=board2)
m2canvas.create_window(450,780,window=board3)
m2canvas.create_window(450,805,window=board4)
m2canvas.create_window(450,830,window=warn7)
m2canvas.create_window(650,730,window=percentage1)
m2canvas.create_window(650,755,window=percentage2)
m2canvas.create_window(650,780,window=percentage3)
m2canvas.create_window(650,805,window=percentage4)
m2canvas.create_window(650,830,window=warn8)
m2canvas.create_window(850,730,window=yop1)
m2canvas.create_window(850,755,window=yop2)
m2canvas.create_window(850,780,window=yop3)
m2canvas.create_window(850,805,window=yop4)
m2canvas.create_window(85,875,window=courses_label)
m2canvas.create_window(285,875,window=bca_btn)
m2canvas.create_window(385,875,window=bcom_btn)
m2canvas.create_window(485,875,window=bsc_btn)
m2canvas.create_window(585,875,window=ba_btn)
m2canvas.create_window(655,950,window=submit_btn)
m2canvas.create_window(735,950,window=reset_btn)
root_0048.mainloop()
conn.close()

# %%
import sqlite3
my_conn = sqlite3.connect('StudentDB1.db')

import tkinter  as tk 
from tkinter import * 
my_w = tk.Tk()
my_w.geometry("400x250") 
r_set=my_conn.execute('''SELECT * from student LIMIT 0,10''');
i=0 # row value inside the loop 
for student in r_set: 
    for j in range(len(student)):
        e = Entry(my_w, width=9, fg='blue')  
        e.insert(END, student[j])
        e.grid(row=i, column=j)
    i+=1
my_w.mainloop()

# %%
from tkinter import *
import tkinter
import tkinter.messagebox
from PIL import Image
from PIL import ImageTk
import urllib.request

master = Tk()
 
def callback():
    print("click!")
    lb = Label(master, image=photoImg)
    lb.pack()

width = 50
height = 50
urllib.request.urlretrieve("https://i.pinimg.com/originals/7b/dd/1b/7bdd1bc7db7fd48025d4e39a0e2f0fd8.jpg",'sample.png')
img = Image.open("sample.png")
img = img.resize((width,height), Image.ANTIALIAS)
photoImg =  ImageTk.PhotoImage(img)
b = Button(master,image=photoImg, command=callback, width=50)
b.pack()
mainloop()
# Out:
# click!
# click!
# click!
# click!
# click!
# click!
# click!
